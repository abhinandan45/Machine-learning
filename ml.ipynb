# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop(columns=["deck","who"],inplace=True)

# %%
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# C:\Users\abhinandan\AppData\Local\Temp\ipykernel_3628\1654433547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
num_features = ['age', 'fare']
df[num_features] = scaler.fit_transform(df[num_features])

# %%
df.head()
# Out:
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male -0.563674      1      0 -0.500240        S  Third
# 1         1       1  female  0.669217      1      0  0.788947        C  First
# 2         1       3  female -0.255451      0      0 -0.486650        S  Third
# 3         1       1  female  0.438050      1      0  0.422861        S  First
# 4         0       3    male  0.438050      0      0 -0.484133        S  Third
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
from sklearn.preprocessing import LabelEncoder
obj_cols = ['adult_male', 'embarked', 'alive', 'alone', 'embark_town', 'class']
obj_df = df[obj_cols].copy()  

label_enc = LabelEncoder()
for col in obj_df.select_dtypes(include=['object', 'category']).columns:
    obj_df[col] = label_enc.fit_transform(obj_df[col].astype(str))

num_df = df.drop(columns=obj_cols)

full_df = pd.concat([num_df, obj_df], axis=1)

# %%
full_df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare  adult_male  \
# 0           0       3    male -0.563674      1      0 -0.500240        True
# 1           1       1  female  0.669217      1      0  0.788947       False
# 2           1       3  female -0.255451      0      0 -0.486650       False
# 3           1       1  female  0.438050      1      0  0.422861       False
# 4           0       3    male  0.438050      0      0 -0.484133        True
# ..        ...     ...     ...       ...    ...    ...       ...         ...
# 886         0       2    male -0.178396      0      0 -0.384475        True
# 887         1       1  female -0.794841      0      0 -0.042213       False
# 888         0       3  female -0.101340      1      2 -0.174084       False
# 889         1       1    male -0.255451      0      0 -0.042213        True
# 890         0       3    male  0.206883      0      0 -0.490173        True
#
#      embarked  alive  alone  embark_town  class
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x='survived',y="sex",data=full_df)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
sns.countplot(x='survived', data=full_df)
plt.title("Survival Count")
plt.show()

# %%
sns.histplot(full_df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
a = df.groupby("sex")["fare"].sum()
a
# Out:
# sex
# female    76.354602
# male     -76.354602
# Name: fare, dtype: float64

# %%
x = full_df[[]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split()
